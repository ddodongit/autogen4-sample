# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console

from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()

api_version = os.getenv("AZURE_OPENAI_API_VERSION")
api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_openai_chat_completion_client = AzureOpenAIChatCompletionClient(
            model=deployment_name,
            azure_endpoint=azure_endpoint,
            api_version=api_version,
            api_key=api_key,
        )

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=azure_openai_chat_completion_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="3일간의 파리 여행 계획짜주세요."))
# Out:
# ---------- TextMessage (user) ----------
# 3일간의 파리 여행 계획짜주세요.
# ---------- TextMessage (planner_agent) ----------
# 파리 3일 여행 일정을 추천해드릴게요!
#
# ---
#
# ### 1일차: 파리의 아이콘과 역사 탐방
# - **에펠탑 (Tour Eiffel)**
#   오전에 방문해 에펠탑 전망대에서 파리 전경을 감상하세요. 미리 티켓을 예매하면 기다리는 시간을 줄일 수 있습니다.
# - **샹드 마르스 공원 (Champ de Mars)**
#   에펠탑 앞 공원에서 사진도 찍고 산책을 즐기세요.
# - **세느강 유람선 (Bateaux Mouches)**
#   에펠탑 근처에서 출발하는 세느강 크루즈를 타고 파리 주요 명소를 강가에서 감상합니다.
# - **앙발리드 (Les Invalides)**
#   나폴레옹의 무덤과 군사 박물관을 볼 수 있습니다.
# - **샤또 드 베르사유(옵션)**
#   시간이 허락하면 베르사유 궁전을 반나절 일정으로 방문해보세요. 파리 외곽이지만 매우 인기있는 명소입니다.
#
# ---
#
# ### 2일차: 예술과 문화의 도시
# - **루브르 박물관 (Musée du Louvre)**
#   아침 일찍 방문해 모나리자를 비롯한 방대한 예술 작품을 감상하세요. 티켓 사전 구매 필수!
# - **튈르리 정원 (Jardin des Tuileries)**
#   루브르 앞 정원에서 휴식과 산책을 즐기세요.
# - **오르세 미술관 (Musée d'Orsay)**
#   인상파 작품들이 많은 곳으로 루브르에서 도보 이동 가능합니다.
# - **몽마르트르 언덕**
#   저녁에는 몽마르트르의 사크레쾨르 대성당과 예술가들의 거리, 카페를 둘러보세요.
#
# ---
#
# ### 3일차: 파리의 매력적인 지역 탐방
# - **노트르담 대성당 (Cathédrale Notre-Dame de Paris)**
#   (복원상태 확인 필요) 시테섬에 위치한 고딕 건축의 명작을 관람하세요.
# - **라탱 지구(Latin Quarter)**
#   고서점과 카페가 많아 파리 문화를 느끼기에 좋은 지역입니다.
# - **생 제르맹 데 프레 (Saint-Germain-des-Prés)**
#   세련된 카페와 부티크가 모여있는 지역에서 점심, 쇼핑을 즐기세요.
# - **샹젤리제 거리 & 개선문 (Champs-Élysées & Arc de Triomphe)**
#   오후와 저녁시간에 샹젤리제 거리를 걷고 개선문에 올라 파리의 야경을 감상하세요.
#
# ---
#
# 즐거운 파리 여행 되시길 바랍니다! 필요한 일정 조정이나 관심사가 있으면 알려주세요.
# ---------- TextMessage (local_agent) ----------
# 파리 3일 여행 일정을 추천해드립니다!
#
# 1일차: 파리의 상징 탐방
# - 오전: 에펠탑 전망대 방문 (미리 티켓 예매 권장)
# - 에펠탑 인근 샹드 마르스 공원 산책 및 사진 촬영
# - 오후: 세느강 유람선 탑승하여 주요 명소 감상
# - 앙발리드 방문 (나폴레옹 무덤 및 군사 박물관)
# - 선택: 시간이 된다면 베르사유 궁전 반나절 투어
#
# 2일차: 예술과 문화 체험
# - 오전: 루브르 박물관 관람 (모나리자 등 명작 감상, 사전 예약 필수)
# - 튈르리 정원에서 휴식
# - 오후: 오르세 미술관 방문 (인상파 명화 감상)
# - 저녁: 몽마르트르 언덕 산책 및 사크레쾨르 대성당 방문, 예술가 거리와 카페 체험
#
# 3일차: 파리의 매력적인 지역 탐방
# - 오전: 노트르담 대성당 관람 (복원 상황 확인할 것)
# - 라탱 지구에서 고서점, 카페 경험
# - 생제르맹 데 프레에서 점심과 쇼핑
# - 오후~저녁: 샹젤리제 거리 산책 후 개선문 전망대에서 야경 감상
#
# 추가로 원하시는 취향이나 관심사에 맞춰 일정 조정도 가능합니다! 즐거운 파리 여행 되세요.
# ---------- TextMessage (language_agent) ----------
# 파리 3일 여행 계획과 일정 추천이 매우 잘 구성되어 있습니다. 두 계획 모두 파리의 대표 명소들을 골고루 포함하고 있으며, 미술관, 역사적 장소, 유명 거리와 카페 등을 균형 있게 배치해 파리의 다양한 매력을 체험할 수 있게 했습니다.
#
# **언어 및 소통 관련 팁을 드리자면:**
#
# - 파리에서는 프랑스어가 공식 언어이나, 주요 관광지, 상점, 호텔, 레스토랑 등 대부분의 관광 서비스에서는 영어가 어느 정도 통합니다.
# - 하지만 현지인에게 예의 바르고 친근하게 다가가기 위해 간단한 프랑스어 인사말이나 표현을 익혀가시는 것을 추천합니다.
#   예) Bonjour (봉주르) - 안녕하세요, Merci (메르시) - 감사합니다, S’il vous plaît (실 부 플레) - 부탁합니다/제발
# - 지도 앱, 번역 앱(예: Google Translate)도 함께 준비하시면 의사소통에 큰 도움이 됩니다.
# - 박물관 티켓이나 여행지 입장권은 사전에 온라인 예약을 권장합니다. 대기 시간을 크게 줄일 수 있습니다.
# - 지하철, 버스 등 대중교통 안내도 프랑스어와 함께 영어 표기도 잘 되어 있어 이동하기 편리합니다.
#
# 전체적으로 현지 언어에 대한 대처 방안이 기본적이고 실용적으로 갖춰져 있어 무난한 여행이 될 것입니다. 추가로 필요하신 숙소 추천, 맛집 리스트, 교통편 안내 등 요청하시면 도움 드릴 수 있습니다. 즐거운 파리 여행 되세요!
# ---------- TextMessage (travel_summary_agent) ----------
# 파리 3일 여행 완벽 일정 추천드립니다. 파리의 상징적인 명소부터 예술과 문화, 매력적인 지역 탐방까지 균형 있게 구성한 여행 플랜입니다.
#
# ---
#
# ## 1일차: 파리의 아이콘과 역사 탐방
# - **오전**
#   - 에펠탑(Tour Eiffel): 아침 일찍 방문해 전망대에서 파리 시내 전경 감상 (온라인 사전 티켓 구매 추천)
#   - 샹드 마르스 공원(Champ de Mars): 에펠탑 앞 넓은 공원에서 산책 및 사진 촬영
# - **점심**
#   - 인근 카페 또는 브라세리에서 프랑스식 식사
# - **오후**
#   - 세느강 유람선(Bateaux Mouches): 세느강을 따라 파리 주요 명소들을 한눈에 감상
#   - 앙발리드(Les Invalides): 나폴레옹 무덤과 군사 박물관 탐방
#   - 선택 방문: 베르사유 궁전(Château de Versailles) - 파리 외곽, 사전 예약하면 반나절 일정으로 다녀올 수 있음
#
# ---
#
# ## 2일차: 예술과 문화 체험
# - **오전**
#   - 루브르 박물관(Musée du Louvre): 세계 최대 미술관에서 모나리자, 밀로의 비너스 등 명작 관람 (사전 예약 필수)
#   - 튈르리 정원(Jardin des Tuileries): 루브르 앞에서 휴식과 산책
# - **점심**
#   - 박물관 주변 카페나 브라세리 이용
# - **오후**
#   - 오르세 미술관(Musée d'Orsay): 인상파 작품 중심의 미술관 방문 (루브르에서 도보 이동 가능)
# - **저녁**
#   - 몽마르트르 언덕: 사크레쾨르 대성당 방문 후 예술가들의 거리와 카페 거리 산책
#
# ---
#
# ## 3일차: 파리의 매력적인 지역 탐방
# - **오전**
#   - 노트르담 대성당(Cathédrale Notre-Dame de Paris): 고딕 건축 명작 관람 (복원상태 사전 확인 권장)
#   - 라탱 지구(Latin Quarter): 고서점과 전통 카페 산책하며 파리 문화를 느끼기
# - **점심**
#   - 생제르맹 데 프레(Saint-Germain-des-Prés): 세련된 카페와 부티크 쇼핑 탐방
# - **오후-저녁**
#   - 샹젤리제 거리(Champs-Élysées): 고급 쇼핑과 거리 산책
#   - 개선문(Arc de Triomphe) 전망대에서 파리 야경 감상
#
# ---
#
# ## 여행 팁
# - **교통:** 파리 지하철(Metro)과 버스가 매우 발달되어 있습니다. 충전식 교통카드인 “Navigo” 또는 “Paris Visite” 카드 권장
# - **언어:** 프랑스어가 공식 언어이나 주요 관광지는 영어 사용 가능. 기본 인삿말(Bonjour, Merci 등)을 익혀가면 현지인과 친근한 소통에 도움
# - **예약:** 루브르, 에펠탑, 베르사유 궁전 등 주요 명소 티켓은 온라인 사전 구매 필수
# - **앱:** Google Maps, Google Translate 등 앱 활용 추천
#
# ---
#
# 필요 시 숙소 추천, 유명 레스토랑, 카페 리스트 등 추가 문의 주세요. 멋진 파리 여행 되길 바랍니다!
#
#
# TERMINATE
# TaskResult(messages=[TextMessage(id='1ade3ac6-1311-4eea-9cbd-c410f009d1a6', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 25, 8, 25, 54, 787725, tzinfo=datetime.timezone.utc), content='3일간의 파리 여행 계획짜주세요.', type='TextMessage'), TextMessage(id='e2841e02-7a34-4c4d-9332-4bec541d72fb', source='planner_agent', models_usage=RequestUsage(prompt_tokens=571, completion_tokens=655), metadata={}, created_at=datetime.datetime(2025, 7, 25, 8, 26, 4, 498403, tzinfo=datetime.timezone.utc), content="파리 3일 여행 일정을 추천해드릴게요!\n\n---\n\n### 1일차: 파리의 아이콘과 역사 탐방\n- **에펠탑 (Tour Eiffel)**  \n  오전에 방문해 에펠탑 전망대에서 파리 전경을 감상하세요. 미리 티켓을 예매하면 기다리는 시간을 줄일 수 있습니다.\n- **샹드 마르스 공원 (Champ de Mars)**  \n  에펠탑 앞 공원에서 사진도 찍고 산책을 즐기세요.\n- **세느강 유람선 (Bateaux Mouches)**  \n  에펠탑 근처에서 출발하는 세느강 크루즈를 타고 파리 주요 명소를 강가에서 감상합니다.\n- **앙발리드 (Les Invalides)**  \n  나폴레옹의 무덤과 군사 박물관을 볼 수 있습니다.\n- **샤또 드 베르사유(옵션)**  \n  시간이 허락하면 베르사유 궁전을 반나절 일정으로 방문해보세요. 파리 외곽이지만 매우 인기있는 명소입니다.\n\n---\n\n### 2일차: 예술과 문화의 도시\n- **루브르 박물관 (Musée du Louvre)**  \n  아침 일찍 방문해 모나리자를 비롯한 방대한 예술 작품을 감상하세요. 티켓 사전 구매 필수!\n- **튈르리 정원 (Jardin des Tuileries)**  \n  루브르 앞 정원에서 휴식과 산책을 즐기세요.\n- **오르세 미술관 (Musée d'Orsay)**  \n  인상파 작품들이 많은 곳으로 루브르에서 도보 이동 가능합니다.\n- **몽마르트르 언덕**  \n  저녁에는 몽마르트르의 사크레쾨르 대성당과 예술가들의 거리, 카페를 둘러보세요.\n\n---\n\n### 3일차: 파리의 매력적인 지역 탐방\n- **노트르담 대성당 (Cathédrale Notre-Dame de Paris)**  \n  (복원상태 확인 필요) 시테섬에 위치한 고딕 건축의 명작을 관람하세요.\n- **라탱 지구(Latin Quarter)**  \n  고서점과 카페가 많아 파리 문화를 느끼기에 좋은 지역입니다.\n- **생 제르맹 데 프레 (Saint-Germain-des-Prés)**  \n  세련된 카페와 부티크가 모여있는 지역에서 점심, 쇼핑을 즐기세요.\n- **샹젤리제 거리 & 개선문 (Champs-Élysées & Arc de Triomphe)**  \n  오후와 저녁시간에 샹젤리제 거리를 걷고 개선문에 올라 파리의 야경을 감상하세요.\n\n---\n\n즐거운 파리 여행 되시길 바랍니다! 필요한 일정 조정이나 관심사가 있으면 알려주세요.", type='TextMessage'), TextMessage(id='4b19de63-8b1e-4e7f-bd4c-e82d1ce0da04', source='local_agent', models_usage=RequestUsage(prompt_tokens=1507, completion_tokens=359), metadata={}, created_at=datetime.datetime(2025, 7, 25, 8, 26, 9, 427009, tzinfo=datetime.timezone.utc), content='파리 3일 여행 일정을 추천해드립니다!\n\n1일차: 파리의 상징 탐방  \n- 오전: 에펠탑 전망대 방문 (미리 티켓 예매 권장)  \n- 에펠탑 인근 샹드 마르스 공원 산책 및 사진 촬영  \n- 오후: 세느강 유람선 탑승하여 주요 명소 감상  \n- 앙발리드 방문 (나폴레옹 무덤 및 군사 박물관)  \n- 선택: 시간이 된다면 베르사유 궁전 반나절 투어\n\n2일차: 예술과 문화 체험  \n- 오전: 루브르 박물관 관람 (모나리자 등 명작 감상, 사전 예약 필수)  \n- 튈르리 정원에서 휴식  \n- 오후: 오르세 미술관 방문 (인상파 명화 감상)  \n- 저녁: 몽마르트르 언덕 산책 및 사크레쾨르 대성당 방문, 예술가 거리와 카페 체험\n\n3일차: 파리의 매력적인 지역 탐방  \n- 오전: 노트르담 대성당 관람 (복원 상황 확인할 것)  \n- 라탱 지구에서 고서점, 카페 경험  \n- 생제르맹 데 프레에서 점심과 쇼핑  \n- 오후~저녁: 샹젤리제 거리 산책 후 개선문 전망대에서 야경 감상\n\n추가로 원하시는 취향이나 관심사에 맞춰 일정 조정도 가능합니다! 즐거운 파리 여행 되세요.', type='TextMessage'), TextMessage(id='762427d3-831c-4939-bd16-6151ae8cb4f8', source='language_agent', models_usage=RequestUsage(prompt_tokens=2255, completion_tokens=360), metadata={}, created_at=datetime.datetime(2025, 7, 25, 8, 26, 14, 116174, tzinfo=datetime.timezone.utc), content='파리 3일 여행 계획과 일정 추천이 매우 잘 구성되어 있습니다. 두 계획 모두 파리의 대표 명소들을 골고루 포함하고 있으며, 미술관, 역사적 장소, 유명 거리와 카페 등을 균형 있게 배치해 파리의 다양한 매력을 체험할 수 있게 했습니다.\n\n**언어 및 소통 관련 팁을 드리자면:**\n\n- 파리에서는 프랑스어가 공식 언어이나, 주요 관광지, 상점, 호텔, 레스토랑 등 대부분의 관광 서비스에서는 영어가 어느 정도 통합니다.\n- 하지만 현지인에게 예의 바르고 친근하게 다가가기 위해 간단한 프랑스어 인사말이나 표현을 익혀가시는 것을 추천합니다.  \n  예) Bonjour (봉주르) - 안녕하세요, Merci (메르시) - 감사합니다, S’il vous plaît (실 부 플레) - 부탁합니다/제발  \n- 지도 앱, 번역 앱(예: Google Translate)도 함께 준비하시면 의사소통에 큰 도움이 됩니다.\n- 박물관 티켓이나 여행지 입장권은 사전에 온라인 예약을 권장합니다. 대기 시간을 크게 줄일 수 있습니다.\n- 지하철, 버스 등 대중교통 안내도 프랑스어와 함께 영어 표기도 잘 되어 있어 이동하기 편리합니다.\n\n전체적으로 현지 언어에 대한 대처 방안이 기본적이고 실용적으로 갖춰져 있어 무난한 여행이 될 것입니다. 추가로 필요하신 숙소 추천, 맛집 리스트, 교통편 안내 등 요청하시면 도움 드릴 수 있습니다. 즐거운 파리 여행 되세요!', type='TextMessage'), TextMessage(id='b202e6e1-68d8-4657-a7fb-e08b06a20024', source='travel_summary_agent', models_usage=RequestUsage(prompt_tokens=3495, completion_tokens=822), metadata={}, created_at=datetime.datetime(2025, 7, 25, 8, 26, 25, 803048, tzinfo=datetime.timezone.utc), content="파리 3일 여행 완벽 일정 추천드립니다. 파리의 상징적인 명소부터 예술과 문화, 매력적인 지역 탐방까지 균형 있게 구성한 여행 플랜입니다.\n\n---\n\n## 1일차: 파리의 아이콘과 역사 탐방\n- **오전**\n ...
