# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console

from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()

api_version = os.getenv("AZURE_OPENAI_API_VERSION")
api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_chat_completion_client = AzureOpenAIChatCompletionClient(
            model="gpt-4o",
            azure_endpoint=azure_endpoint,
            api_version=api_version,
            api_key=api_key,
)

# %%
planner_agent = AssistantAgent(
    "planner_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=azure_openai_chat_completion_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=azure_openai_chat_completion_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Seoul."))
# Out:
# ---------- TextMessage (user) ----------
# Plan a 3 day trip to Seoul.
# ---------- TextMessage (planner_agent) ----------
# Here’s a 3-day travel itinerary for Seoul, South Korea, balancing iconic attractions, local experiences, and delicious food!
#
# ---
#
# ### **Day 1: Historic and Cultural Seoul**
# **Morning:**
# - **Gyeongbokgung Palace**: Start your trip at Seoul’s most iconic royal palace. Time your visit for the **changing of the guard ceremony** (10:00 AM or 2:00 PM).
#   - **Rental suggestion**: Dress in a traditional Korean hanbok (available nearby) for free admission and unique photos.
# - **National Folk Museum of Korea**: Located within the palace complex, it’s a quick stop to learn about traditional Korean lifestyles.
#
# **Lunch**:
# - Try **Samgyetang** (ginseng chicken soup) at **Tosokchon Samgyetang**, a short walk from the palace.
#
# **Afternoon:**
# - **Bukchon Hanok Village**: Stroll through Seoul’s historic neighborhood with traditional Korean houses (hanok). Enjoy stunning views of modern Seoul juxtaposed with old-world charm.
# - **Insadong Street**: Explore this vibrant neighborhood, famous for its art galleries, tea houses, and souvenir shops. Look out for vendors selling Korean street snacks like hotteok (sweet pancakes).
#
# **Dinner**:
# - Head to **Jongno 3-ga** for Korean BBQ. Try restaurants like **Maple Tree House** or **Woo Lae Oak**.
#
# **Evening:**
# - **Cheonggyecheon Stream**: End your day with a relaxing walk along this beautifully lit urban stream in the heart of the city.
#
# ---
#
# ### **Day 2: Modern Seoul**
# **Morning:**
# - **Namdaemun Market**: Grab a hearty breakfast of Korean street food (hotteok, mandu, or gimbap) at Seoul’s largest traditional market.
# - **Namsan Seoul Tower (N Seoul Tower)**: Take the cable car or hike up Namsan Mountain to Seoul’s iconic tower. Visit the observatory for stunning panoramic views of the city, and don’t miss the **Locks of Love** area.
#
# **Lunch**:
# - Dine at one of the restaurants near Myeongdong, such as **Kyochon** for Korean fried chicken or a hearty bowl of **Bibimbap** at a local eatery.
#
# **Afternoon:**
# - **Myeongdong Shopping Street**: Shop for Korean cosmetics, fashion, and quirky souvenirs. Don’t miss snacking on Korean street food favorites like tteokbokki (spicy rice cakes) and eomuk (fish cake).
# - **Dongdaemun Design Plaza (DDP)**: Explore this futuristic architectural landmark. In the late afternoon, visit the **LED Rose Garden**, especially enchanting at sunset.
#
# **Dinner:**
# - Try **Jjimdak** (Korean braised chicken) at **Andong Jjimdak** or resist the spicy allure of **Buldak** (fire chicken).
#
# **Evening:**
# - **Han River Cruise**: Enjoy an evening cruise along the Han River, with beautiful views of the city skyline. Some cruises offer live music or buffet options.
#
# ---
#
# ### **Day 3: Nature and Local Neighborhoods**
# **Morning:**
# - **Changdeokgung Palace & Secret Garden**: Tour this UNESCO World Heritage Site, known for its harmonious architecture and lush gardens.
# - **Ikseon-dong Hanok Village**: A picturesque area blending modern cafés and boutiques within charming traditional hanok houses. A perfect spot for morning coffee or brunch.
#
# **Lunch:**
# - Enjoy **Kalguksu** (knife-cut noodles) or **Bulgogi** (marinated beef) in one of Ikseon-dong’s trendy restaurants.
#
# **Afternoon:**
# - **Hongdae**: Explore Hongdae’s youthful, art-driven neighborhood. Check out indie shops, unique street murals, and local cafés. If it’s the weekend, catch the **Hongdae Free Market** featuring handmade crafts and live performances.
# - **Yeouido Hangang Park**: Ride a bike along the river or just relax in this scenic urban park.
#
# **Dinner:**
# - **Gangnam**: Head south to the famous Gangnam district for fine dining or trendy eateries. Try dishes like **Bossam** (pork wraps) or **Naengmyeon** (cold noodles).
#
# **Evening:**
# - Wrap up your trip at a **K-pop-themed café** in Gangnam or enjoy the nightlife at a **Karaoke (Noraebang)** or a rooftop lounge bar.
#
# ---
#
# ### Additional Tips:
# - **Public Transport**: Get a **T-money card** for easy subway and bus rides.
# - **Language**: Learn basic Korean phrases, but Seoul is quite tourist-friendly with English signage.
# - **Seasonal Considerations**: In spring, enjoy the cherry blossoms; in autumn, visit for beautiful fall foliage.
#
# Have a fantastic time in Seoul! 🇰🇷🍜🛕
# /Users/andy/works/ai/autogen04-sample/.venv/lib/python3.11/site-packages/autogen_agentchat/agents/_assistant_agent.py:981: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-11-20. Model mapping in autogen_ext.models.openai may be incorrect. Set the model to gpt-4o-2024-11-20 to enhance token/cost estimation and suppress this warning.
#   model_result = await model_client.create(
# ---------- TextMessage (local_agent) ----------
# Let me know if you’d like recommendations tailored to specific interests (e.g., foodies, history buffs, shopping enthusiasts)!
# ---------- TextMessage (language_agent) ----------
# Your plan covers an excellent balance of Seoul's historical, modern, and cultural highlights, while also integrating dining, shopping, and nature experiences. The tips for public transport (T-money card) and seasonal awareness are highly practical. Regarding language preparedness:
#
# 1. **Satisfactory Language Tips**: You've included a suggestion to learn basic Korean phrases and noted that Seoul is tourist-friendly with English signage. This is sufficient for most travelers visiting Seoul, where key attractions and services often cater to English-speaking visitors.
#
# 2. **Additional Suggestions**:
#    - Travelers could download translation apps like **Google Translate** with Offline Korean features or use phrase apps like **Papago**. These are especially helpful for interactions at smaller restaurants or markets.
#    - Key Korean travel phrases like "Where is ___?" (____은 어디예요?/____eun eodi yeyo?) or "Thank you" (감사합니다/Gamsahamnida) might be worth mentioning for added convenience.
#
# Overall, your plan is very well-rounded and equipped to handle potential language or communication challenges! 😊
# ---------- TextMessage (travel_summary_agent) ----------
# Here is the finalized, detailed 3-day Seoul travel plan integrating all perspectives:
#
# ---
#
# ### ⭐ **3-Day Seoul Travel Itinerary** ⭐
#
# #### **Day 1: Historic and Cultural Seoul**
# **Morning:**
# - **Gyeongbokgung Palace**:
#   - Begin your journey with a visit to this iconic royal palace. Witness the **changing of the guard ceremony** (10:00 AM or 2:00 PM).
#   - **Pro Tip**: Rent a traditional **Korean hanbok** from nearby stores for free entry into the palace and for memorable photos.
# - **National Folk Museum of Korea**: Located within the palace, explore exhibits about traditional Korean lifestyles.
#
# **Lunch**:
# - Keep it local by savoring **Samgyetang** (ginseng chicken soup) at **Tosokchon Samgyetang**, a historic restaurant nearby.
#
# **Afternoon:**
# - **Bukchon Hanok Village**:
#   - Wander through this historic area featuring traditional Korean homes (hanoks). It offers excellent photo opportunities with the city as a backdrop.
# - **Insadong Street**:
#   - Dive into the artsy atmosphere of Insadong. Check out handmade crafts, traditional tea houses, and local snacks like **hotteok** (sweet pancakes).
#
# **Dinner**:
# - Head to **Jongno 3-ga** for an authentic Korean BBQ experience. Restaurants like **Maple Tree House** or **Woo Lae Oak** are excellent options.
#
# **Evening:**
# - Wrap up the day at **Cheonggyecheon Stream**. This revitalized urban stream is ideal for a quiet stroll in the evening under beautifully illuminated lights.
#
# ---
#
# #### **Day 2: Modern Seoul**
# **Morning:**
# - **Namdaemun Market**:
#   - Grab breakfast street-food-style at South Korea’s largest traditional market. Try **mandu** (dumplings), **gimbap** (Korean sushi rolls), or **hotteok** (sweet pancakes).
# - **Namsan Seoul Tower (N Seoul Tower)**:
#   - Take the cable car to the top of Namsan Mountain for stunning views of the city.
#   - Visit the observatory, and don’t miss the **Locks of Love** area.
#
# **Lunch**:
# - Refuel with Korean fried chicken at **Kyochon**, famous for its crispy texture, or enjoy a bowl of **Bibimbap** in nearby restaurants.
#
# **Afternoon:**
# - **Myeongdong Shopping Street**:
#   - Shop for cosmetics, fashion, and souvenirs while tasting street food classics like **tteokbokki** (spicy rice cakes) and **eomuk** (fish cake skewers).
# - **Dongdaemun Design Plaza (DDP)**:
#   - Explore this futuristic cultural hub with galleries, exhibitions, and a nighttime **LED Rose Garden** that’s especially magical at dusk.
#
# **Dinner**:
# - Try **Jjimdak** (Korean braised chicken) at **Andong Jjimdak** or embrace the heat with spicy **Buldak** (fire chicken).
#
# **Evening:**
# - **Han River Cruise**:
#   - Set sail on an evening cruise along Seoul's glowing skyline. Opt for a cruise with live music or themed activities for a dynamic experience.
#
# ---
#
# #### **Day 3: Nature and Local Neighborhoods**
# **Morning:**
# - **Changdeokgung Palace**:
#   - Visit this UNESCO World Heritage site, renowned for the **Secret Garden** that reflects Korea’s harmony with nature.
# - **Ikseon-dong Hanok Village**:
#   - Stroll through this charming area with hanok-style buildings transformed into modern cafés and boutiques. Stop for a cozy coffee or light brunch.
#
# **Lunch**:
# - Enjoy **Kalguksu** (knife-cut noodles) or **Bulgogi** (marinated beef) at a local dining spot in Ikseon-dong.
#
# **Afternoon:**
# - **Hongdae**:
#   - Venture into Hongdae, famous for its youthful vibe, indie shops, and street art. On weekends, catch the **Hongdae Free Market** featuring local crafts and live performances.
# - **Yeouido Hangang Park**:
#   - Explore this serene park by biking along the Han River or simply relax and enjoy the view.
#
# **Dinner**:
# - Travel to **Gangnam** to experience its vibrant dining scene. Try **Bossam** (pork wraps) or **Naengmyeon** (cold buckwheat noodles) at one of the district’s trendy eateries.
#
# **Evening:**
# - Close your Seoul adventure with K-pop-inspired activities in Gangnam—visit a themed café or sing your heart out at a **Karaoke (Noraebang)**. Alternatively, enjoy a rooftop lounge bar with city views.
#
# ---
#
# ### 🎒 **Practical Tips**
# 1. **Transport**:
#    - Obtain a **T-money card** for convenient public transportation on buses and subways.
# 2. **Language**:
#    - Download translation apps like **Google Translate** or **Papago** to help with communication in smaller markets or restaurants.
#    - Learn a few handy Korean phrases:
#      - Hello: 안녕하세요 (Annyeonghaseyo)
#      - Thank You: 감사합니다 (Gamsahamnida)
#      - Where is ___?: ____은 어디예요? (____eun eodi yeyo?)
# 3. **Seasonal Highlights**:
#    - Spring: Enjoy cherry blossoms at palaces and parks.
#    - Fall: Admire the brilliant autumn foliage at Changdeokgung's Secret Garden.
#
# ---
#
# ### 🌐 **Why This Plan is Perfect**
# This itinerary offers a well-rounded experience, balancing historical landmarks, vibrant neighborhoods, local food, and scenic nature spots. It includes both must-see attractions and hidden gems, fostering a unique and immersive cultural journey.
#
# Enjoy your 3 days in Seoul, the perfect blend of old-world charm and modern vibrancy! 🇰🇷✨
#
# TERMINATE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 6, 20, 7, 23, 38, 453522, tzinfo=datetime.timezone.utc), content='Plan a 3 day trip to Seoul.', type='TextMessage'), TextMessage(source='planner_agent', models_usage=RequestUsage(prompt_tokens=40, completion_tokens=1030), metadata={}, created_at=datetime.datetime(2025, 6, 20, 7, 23, 50, 659109, tzinfo=datetime.timezone.utc), content='Here’s a 3-day travel itin